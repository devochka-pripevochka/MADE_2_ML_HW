# %%
import numpy as np
from collections import Counter
import pandas as pd
import re
import random

# %% [markdown]
# # 1

# %%
corpus = 'AnnaKarenina.txt'

def clean_text(text):
    return re.sub(r"\W+", " ", ''.join(text)).lower()

with open(corpus, 'r') as f:
    corpus = f.readlines()
    
corpus = clean_text(corpus)

# %%
def ngram_freq_dict(text):
    c = Counter(text)
    dl = len(text)
    
    result = []
    
    for k, v in c.items():
        result.append((k, v / dl))
    result = sorted(result, key=lambda x: x[1], reverse=True)
    
    return result

# %%
def encode_mapping(symbols):
    encoded = symbols.copy()
    random.shuffle(encoded)
    
    result = {}
    
    for o, e in zip(symbols, encoded):
        result[o] = e
        
    return result

# %%
def apply_mapping(text, e_dict):
    result = str()
    for c in text:
        result += e_dict[c]
        
    return result

# %%
def decode(corp_freq, text_freq, method='rank'):
    result = {}
    if method == 'rank':
        for i in range(min(len(corp_freq), len(text_freq))):
            result[text_freq[i][0]] = corp_freq[i][0]
    elif method == 'closest':
        for c, prob in text_freq:
            best_dist = 10
            best_char = None
            for cc, pp in corp_freq:
                if abs(pp - prob) < best_dist:
                    best_dist = abs(pp - prob)
                    best_char = cc
            result[c] = best_char
            
    return result

# %%
def accuracy(enc_dict, dec_dict):
    counter = 0
    for a, b in enc_dict.items():
        try:
            if dec_dict[b] == a:
                counter += 1
        except:
            pass
        
    return counter / len(enc_dict)

# %%
def encode_decode(text, corpus, method='closest'):
    text = clean_text(text)
    enc_dict = encode_mapping(list(set(text)))
    enc_text = apply_mapping(text, enc_dict)
    corp_freq = ngram_freq_dict(corpus)
    enc_freq = ngram_freq_dict(enc_text)
    dec_dict = decode(corp_freq, enc_freq, method)
    print(apply_mapping(enc_text, dec_dict))
    print('\n')
    print(text)
    print('\nAccuracy of dictionary: ', accuracy(enc_dict, dec_dict))

# %%
test = clean_text('Война и мир" – самый известный роман Льва Николаевича Толстого, как никакое другое произведение писателя, отражает глубину его мироощущения и философии.	Эта книга из разряда вечных, потому что она обо всем – о жизни и смерти, о любви и чести, о мужестве и героизме, о славе и подвиге, о войне и мире.	Первый том знакомит с высшим обществом России XIX века. Показаны взаимоотношения между родителями и детьми в семье Ростовых, сватовство у Болконских, интриги у Безуховых, вечера в салоне фрейлины А.П.Шерер, балы в Москве и Петербурге.')

# %%
encode_decode(test, corpus)
# Out:
# иозли о вол ливпз опиелслпз ловил дхии ломодиеиожи содлсояо мим ломимое злуяое ылоопиезелое ыолиседж ослишиес ядуыолу еяо волоохухелож о ходолохоо цси млояи оп липлжзи иежлпж ыосову жсо оли оыо илев о шопло о лвелсо о дцыио о желсо о вушелсие о яелоопве о лдиие о ыозиояе о иозле о воле ыелипз сов плимовос л иплхов оыхелсиов лоллоо эцэ иеми ыомипилп ипиовоослохелож вешзу лозоседжво о зесхво и левхе лолсоипж лиисоилсио у ыодмоллмож олслояо у ыепужоипж иежели и лидоле хлездолп и ы хелел ыидп и волмие о ыеселыуляе
#
#
# война и мир самый известный роман льва николаевича толстого как никакое другое произведение писателя отражает глубину его мироощущения и философии эта книга из разряда вечных потому что она обо всем о жизни и смерти о любви и чести о мужестве и героизме о славе и подвиге о войне и мире первый том знакомит с высшим обществом россии xix века показаны взаимоотношения между родителями и детьми в семье ростовых сватовство у болконских интриги у безуховых вечера в салоне фрейлины а п шерер балы в москве и петербурге
#
# Accuracy of dictionary:  0.12121212121212122

# %%
encode_decode(test, corpus, method='rank')
# Out:
# нобви е рес лируб епналтвуб сорив кшни ведокианечи токлтояо дид ведидоа гсмяоа ьсоепнагавеа ьелитакз отсийиат якмыевм аяо ресоохмхавез е юеколоюее цти двеяи еп сипсзги начвуж ьоторм что ови оыо нлар о йепве е лрасте о кфыне е чалте о рмйалтна е яасоепра о лкина е ьогнеяа о нобва е реса ьаснуб тор пвидорет л нулэер оыхалтнор соллее щ1щ нади ьодипиву нпиероотвоэавез райгм согетакзре е гатшре н ларша солтонуж лнитонлтно м ыокдовлдеж евтсеяе м ыапмжонуж начаси н ликова юсабкеву и ь эасас ыику н ролдна е ьатасымсяа
#
#
# война и мир самый известный роман льва николаевича толстого как никакое другое произведение писателя отражает глубину его мироощущения и философии эта книга из разряда вечных потому что она обо всем о жизни и смерти о любви и чести о мужестве и героизме о славе и подвиге о войне и мире первый том знакомит с высшим обществом россии xix века показаны взаимоотношения между родителями и детьми в семье ростовых сватовство у болконских интриги у безуховых вечера в салоне фрейлины а п шерер балы в москве и петербурге
#
# Accuracy of dictionary:  0.12121212121212122

# %%
secret = 'დჳჵჂႨშႼႨშჂხჂჲდႨსႹႭჾႣჵისႼჰႨჂჵჂႨႲႹႧჲჂႨსႹႭჾႣჵისႼჰႨჲდႩჳჲႨჇႨႠჲႹქႹႨჳႹႹჱჶდსჂႽႨႩႹჲႹႭႼჰႨჵდქႩႹႨႲႭႹႧჂჲႣჲიႨჳႩႹႭდდႨშჳდქႹႨშႼႨშჳდႨჳხდჵႣჵჂႨႲႭႣშჂჵისႹႨჂႨႲႹჵჇႧჂჲდႨჾႣႩჳჂჾႣჵისႼჰႨჱႣჵჵႨეႣႨႲႹჳჵდხსდდႨႧდჲშდႭჲႹდႨეႣხႣსჂდႨႩჇႭჳႣႨႾႹჲႽႨႩႹსდႧსႹႨႽႨსჂႧდქႹႨსდႨႹჱდჶႣნ'

# %%
corp_freq = ngram_freq_dict(corpus)
enc_freq = ngram_freq_dict(secret)
dec_dict = decode(corp_freq, enc_freq, method='rank')
print(apply_mapping(secret, dec_dict))
# Out:
# олна рд раяасо иевьтнуиды ана пемса иевьтнуиды соклс б шсеге леечжоиаз кесевды ногке пвемастсу лкевоо рлоге рд рло ляонтна пвтрануие а пенбмасо ьтклаьтнуиды чтнн йт пелнояиоо мосровсео йтятиао кбвлт хесз кеиомие з иамоге ио ечожтю

# %% [markdown]
# # 2

# %%
def get_ngram_freq_list(text, ngram=2, use_freq=True):
    result = []
    c = Counter()
    dl = len(text) - ngram + 1 
    
    for i in range(dl):
        c.update([text[i:i + ngram]])
    if use_freq:
        for b, n in c.items():
            result.append((b, n / dl))
    else:
        for b, n in c.items():
            result.append((b, n))
            
    return sorted(result, key=lambda x: x[1], reverse=True)

# %%
def ngram_decode(text, dec_dict):
    result = []
    ngram = len(list(dec_dict.keys())[0])
    
    for i in range(0, len(text), ngram):
        try:
            b = dec_dict[text[i:i + ngram]]
            result.append(b)
        except:
            pass
        
    return ''.join(result)

# %%
enc_dict = encode_mapping(list(set(test)))
enc_text = apply_mapping(test, enc_dict)
corp_freq = get_ngram_freq_list(corpus)
enc_freq = get_ngram_freq_list(enc_text)
dec_dict = decode(corp_freq, enc_freq, method='rank')

# %%
print(ngram_decode(enc_text, dec_dict))
# Out:
# онтаи о ноомм х роалтоя коро имутвивдеетилрари бслсерая ев нкаоенакание мануве п иалтооднае амм тьаз ваквыриатруча мгоее нно иисдиотема  рбелазнитожсвчтнаиза салоекляи тоняол пос тгосп нв и ас нвсю  вочалнаа  оороко  нидшио о моя о  неггля тоа быь дадре  нтыжие о вакун е  нонтае о норе пь енростовче ч тме о сепсиовасжея онов иихитебмн сньи вакас ко сс  эинанькотемнеьнум койме уымо о одпано с ою ул кластен доп зеря онкискранибрз  д макн о гоутозусен дтомоло с осьв е жнбуугкод  пыеь ь сксь еленыэттоа  пель ксшае

# %%
print(test)
# Out:
# война и мир самый известный роман льва николаевича толстого как никакое другое произведение писателя отражает глубину его мироощущения и философии эта книга из разряда вечных потому что она обо всем о жизни и смерти о любви и чести о мужестве и героизме о славе и подвиге о войне и мире первый том знакомит с высшим обществом россии xix века показаны взаимоотношения между родителями и детьми в семье ростовых сватовство у болконских интриги у безуховых вечера в салоне фрейлины а п шерер балы в москве и петербурге

# %% [markdown]
# # 3, 4

# %%
def l_to_d(freq_list):
    result = {}
    for c, n in freq_list:
        result[c] = n
        
    return result

# %%
def dict_accuracy(text, decode_dict, corp_freq, ngram=2):
    score = 0
    decrypted_text = apply_mapping(text, decode_dict)
    decrypted_freq = l_to_d(get_ngram_freq_list(decrypted_text, ngram=ngram, use_freq=False))
    for k, v in decrypted_freq.items():
        if k in corp_freq:
            score += v * np.log(corp_freq[k])
            
    return score

# %%
def dec_dict(dec_dict, keep_spaces=False):
    keys = None
    
    if keep_spaces:
        while keys == None:
            keys = random.sample(dec_dict.keys(), 2)
            if dec_dict[keys[0]] == ' ' or dec_dict[keys[1]] == ' ':
                keys = None
    else:
        keys = random.sample(dec_dict.keys(), 2)
    new_dict = dec_dict.copy()
    new_dict[keys[0]], new_dict[keys[1]] = new_dict[keys[1]], new_dict[keys[0]]
    
    return new_dict

# %%
def rand(p):
    if random.random() > p:
        return False
    else:
        return True

# %%
def make_dict(text, corpus):
    result = {}
    text_freq = ngram_freq_dict(text)
    corp_freq = ngram_freq_dict(corpus)
    for i in range(len(text_freq)):
        result[text_freq[i][0]] = corp_freq[i][0]
    for i in range(len(text_freq), 34):
        result['_' * i] = corp_freq[i][0]
        
    return result

# %%
def dec_mcmc(text, corp_freq, n_iter=10000, corpus=corpus, ngram=2, print_progress=True):
    cur_decode_dict = make_dict(text, corpus)
    best_dict = None
    score = -1e+40
    
    for i in range(n_iter):
        new_decode_dict = dec_dict(cur_decode_dict, keep_spaces=True)
        cur_score = dict_accuracy(text, cur_decode_dict, corp_freq, ngram=ngram)
        new_score = dict_accuracy(text, new_decode_dict, corp_freq, ngram=ngram)
        acceptance_prob = min(1, np.exp(new_score - cur_score))
        if cur_score > score:
            score = cur_score
            best_dict = cur_decode_dict
        if rand(acceptance_prob):
            cur_decode_dict = new_decode_dict
        if (i + 1) % 500 == 0 and print_progress:
            print(i, ':', apply_mapping(text, best_dict))
            print(score)
            
    return best_dict

# %%
corp_freq = get_ngram_freq_list(corpus, ngram=2, use_freq=False)
corp_freq_dict = l_to_d(corp_freq)
best_dict = dec_mcmc(secret, corp_freq_dict, 20000)
# Out:
# 499 : оква бы бачаро недствшный ава зегра недствшный роикр я преже кееухонам иередый вожие здегартрш киедоо бкоже бы бко кчовтва здтбавшне а зевягаро стикаствшный утвв эт зеквочноо горбодрео этчтнао иядкт щерм иеногне м нагоже но еуохтл
# 1884.490775990959
# 999 : оква бы бачаро недутвьный ава легра недутвьный роикр з хреме кееспоная иередый вомие лдегартрь киедоо бкоме бы бко кчовтва лдтбавьне а левзгаро утикаутвьный ствв эт леквочноо горбодрео этчтнао издкт шеря иеногне я нагоме но есоптю
# 1902.2483607350034
# 1499 : окса бы баларо невчтсьный аса дегра невчтсьный роикр з преме кееушоная иеревый сомие двегартрь киевоо бкоме бы бко клостса двтбасьне а десзгаро чтикачтсьный утсс эт дексолноо горбоврео этлтнао извкт херя иеногне я нагоме но еуоштц
# 1917.4281557226518
# 1999 : осла бы бакаро нетчильный ала дегра нетчильный ровср я зреме сеепшонау веретый ломве дтегарирь светоо бсоме бы бсо сколила дтибальне а делягаро чивсачильный пилл эи деслокноо горботрео эикинао вятси жеру веногне у нагоме но епошию
# 1951.5085877960178
# 2499 : овли зы зимиро нетчальный или пегри нетчальный росвр у бреже веедшония серетый ложсе птегирарь всетоо звоже зы зво вмолали птазильне и пелугиро часвичальный далл ка певломноо горзотрео каманио сутва церя сеногне я нигоже но едошах
# 1977.7810354560324
# 2999 : овли зы зидито нергальный или пемти нергальный тосвт у чтеже веебхония сетерый ложсе премитать всероо звоже зы зво вдолали празильне и пелумито гасвигальный балл ка певлодноо мотзортео каданио сурва шетя сеномне я ниможе но ебохаю
# 1988.0586934285045
# 3499 : окли вы визито нердальный или пемти нердальный тоскт у чтеже кеебгония сетерый ложсе премитать ксероо вкоже вы вко кзолали правильне и пелумито даскидальный балл ха пеклозноо мотвортео хазанио сурка шетя сеномне я ниможе но ебогаю
# 1997.7858142287405
# 3999 : окли вы визито нербальный или пемти нербальный тоскт у чтеже кеегдония сетерый ложсе премитать ксероо вкоже вы вко кзолали правильне и пелумито баскибальный галл ха пеклозноо мотвортео хазанио сурка шетя сеномне я ниможе но егодаю
# 1998.3643047794155
# 4499 : осли вы визито нергальный или пемти нергальный тодст у чтеже сеебкония детерый ложде премитать сдероо всоже вы всо сзолали правильне и пелумито гадсигальный балл ха песлозноо мотвортео хазанио дурса шетя деномне я ниможе но ебокаю
# 2003.9275521166358
# 4999 : осли вы викито нершальный или пемти нершальный тодст у этеже сеезгония детерый ложде премитать сдероо всоже вы всо сколали правильне и пелумито шадсишальный залл ча песлокноо мотвортео чаканио дурса бетя деномне я ниможе но езогах
# 2016.8956210318631
# 5499 : осли вы викито нершальный или пемти нершальный тодст у этеже сеезгония детерый ложде премитать сдероо всоже вы всо сколали правильне и пелумито шадсишальный залл ча песлокноо мотвортео чаканио дурса бетя деномне я ниможе но езогах
# 2016.8956210318631
# 5999 : осли вы викито нершальный или пемти нершальный тодст у этеже сеезгония детерый ложде премитать сдероо всоже вы всо сколали правильне и пелумито шадсишальный залл ча песлокноо мотвортео чаканио дурса бетя деномне я ниможе но езогах
# 2016.8956210318631
# 6499 : осли вы викито нерчальный или пемти нерчальный тодст у этеже сеезгония детерый ложде премитать сдероо всоже вы всо сколали правильне и пелумито чадсичальный залл ба песлокноо мотвортео баканио дурса шетя деномне я ниможе но езогах
# 2018.0394446331811
# 6999 : осли вы викито нерчальный или пемти нерчальный тодст у этеже сеезгония детерый ложде премитать сдероо всоже вы всо сколали правильне и пелумито чадсичальный залл ба песлокноо мотвортео баканио дурса шетя деномне я ниможе но езогах
# 2018.0394446331811
# 7499 : если вы вимите норчальный или подти норчальный текст у этого сообжения который легко продитать скорее всего вы все смелали правильно и полудите чаксичальный балл за послемнее детвертое замание курса шотя конедно я нидего не обежаю
# 2038.7958999433718
# 7999 : если вы вимите норчальный или подти норчальный текст у этого соожшения который легко продитать скорее всего вы все смелали правильно и полудите чаксичальный жалл за послемнее детвертое замание курса ботя конедно я нидего не ожешаю
# 2039.0106291641519
# 8499 : если вы вимите норбальный или почти норбальный текст у этого соождения который легко прочитать скорее всего вы все смелали правильно и получите баксибальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожедаю
# 2042.0600343037343
# 8999 : если вы вимите нордальный или почти нордальный текст у этого соожбения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаш
# 2044.6155815892812
# 9499 : если вы вимите нордальный или почти нордальный текст у этого соожбения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаш
# 2044.6155815892812
# 9999 : если вы вимите нордальный или почти нордальный текст у этого соожбения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаю
# 2044.8907679197473
# 10499 : если вы вимите нордальный или почти нордальный текст у этого соожбения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаю
# 2044.8907679197473
# 10999 : если вы вимите нордальный или почти нордальный текст у этого соожбения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаю
# 2044.8907679197473
# 11499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаю
# 2045.3469205703875
# 11999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаю
# 2045.3469205703875
# 12499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 12999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 13499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 13999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 14499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 14999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 15499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 15999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 16499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 16999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 17499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 17999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 18499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 18999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 19499 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648
# 19999 : если вы вимите нордальный или почти нордальный текст у этого сообщения который легко прочитать скорее всего вы все смелали правильно и получите даксидальный балл за послемнее четвертое замание курса хотя конечно я ничего не обещаж
# 2045.6392183087648

# %% [markdown]
# # 5

# %%
for i in range(2, 11):
    corp_freq = get_ngram_freq_list(corpus, ngram=i, use_freq=False)
    corp_freq_dict = l_to_d(corp_freq)
    best_dict = dec_mcmc(secret, corp_freq_dict, 20000, ngram=i, print_progress=False)
    print('Ngram =', i)
    print(apply_mapping(secret, best_dict))
# Out:
# Ngram = 2
# отни кс кидило верманывсь ини пегли верманывсь лочтл у элеже теебховия челерсь ножче прегилалы тчероо ктоже кс кто тдонани пракиныве и пенугило мачтиманывсь банн за петнодвоо голкорлео задавио чурта шеля чевогве я вигоже во ебохай
# Ngram = 3
# если вы видите нормальный или почти нормальный текст у этого сообщения который легко прочитать скорее всего вы все сделали правильно и получите максимальный балл за последнее четвертое задание курса хотя конечно я ничего не обещаю
# Ngram = 4
# если вы видите нормальный или почти нормальный текст у этого сообщения который легко прочитать скорее всего вы все сделали правильно и получите максимальный балл за последнее четвертое задание курса хотя конечно я ничего не обещаю
# Ngram = 5
# если вы видите нормальный или почти нормальный текст у этого сообщения который легко прочитать скорее всего вы все сделали правильно и получите максимальный балл за последнее четвертое задание курса хотя конечно я ничего не обещаю
# Ngram = 6
# ежмй ул уйкйое свадьмысли ймй цвной свадьмысли оетжо я говрв жввпчесйe твовали мертв цавнйоьоы жтваее ужерв ул уже жкемьмй цаьуймысв й цвмянйое дьтжйдьмысли пьмм 1ь цвжмексее неоуеаове 1ькьсйе тяажь фвоe твсенсв e сйнерв се впечьз
# Ngram = 7
# мэак зг зкхктм еуы1вашего как будтк еуы1вашего тмпэт ц фтуйу эуусямекь путуыго амйпу быудктвтш эпуымм зэмйу зг зэм эхмавак бывзкашеу к буацдктм 1впэк1вашего сваа ив буэамхемм дмтзмытум ивхвекм пцыэв чуть пуемдеу ь екдмйу ем усмявж
# Ngram = 8
# олна рд раяасо иевьтнуиды ана пемса иевьтнуиды соклс б шсеге леечжоиаз кесевды ногке пвемастсу лкевоо рлоге рд рло ляонтна пвтрануие а пенбмасо ьтклаьтнуиды чтнн йт пелнояиоо мосровсео йтятиао кбвлт хесз кеиомие з иамоге ио ечожтю
# Ngram = 9
# олна рд раяасо иевьтнуиды ана пемса иевьтнуиды соклс б шсеге леечжоиаз кесевды ногке пвемастсу лкевоо рлоге рд рло ляонтна пвтрануие а пенбмасо ьтклаьтнуиды чтнн йт пелнояиоо мосровсео йтятиао кбвлт хесз кеиомие з иамоге ио ечожтю
# Ngram = 10
# олна рд раяасо иевьтнуиды ана пемса иевьтнуиды соклс б шсеге леечжоиаз кесевды ногке пвемастсу лкевоо рлоге рд рло ляонтна пвтрануие а пенбмасо ьтклаьтнуиды чтнн йт пелнояиоо мосровсео йтятиао кбвлт хесз кеиомие з иамоге ио ечожтю

# %% [markdown]
# ### 3-5-граммы получше
